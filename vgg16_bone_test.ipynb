# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# %%
train = '/mnt/newvolume/DUMP/Notebook/xray_class/data/dataset_4/train'
test = '/mnt/newvolume/DUMP/Notebook/xray_class/data/dataset_4/valid'

gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#Preprocessing

# %%
def scale_images(x, y):
    return x / 255, y

# %%
train_data = tf.keras.utils.image_dataset_from_directory(train, image_size=(256, 256), labels="inferred", label_mode="binary", validation_split=0.2, subset="training",seed=42)
train_data = train_data.map(scale_images)
train_size = int(len(train_data))
train_data_final = train_data.take(train_size)
print(train_size)
# Out:
# Found 8621 files belonging to 2 classes.
# Using 6897 files for training.
# 216

# %%
val_data = tf.keras.utils.image_dataset_from_directory(train, image_size=(256, 256), labels="inferred", label_mode="binary", validation_split=0.2, subset="validation", seed=42)
val_data = val_data.map(scale_images)
val_data_final = val_data.take(len(val_data))
print(len(val_data))
# Out:
# Found 8621 files belonging to 2 classes.
# Using 1724 files for validation.
# 54

# %%
#VGG16

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import SGD, Adam

vgg16_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

for layers in vgg16_model.layers:
    layers.trainable = False

vgg16_model.summary()

model = Sequential()

model.add(vgg16_model)

model.add(Flatten())

model.add(Dense(32, activation='relu'))

model.add(Dense(1, activation='sigmoid'))

cus_optimizer = SGD(learning_rate = 0.0001)

model.compile(optimizer=cus_optimizer, loss='binary_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 32)                1048608
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 15,763,329
# Trainable params: 1,048,641
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
logdir='logs'
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
history = model.fit(train_data_final, epochs=5, validation_data=val_data_final, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/5
# 216/216 [==============================] - 225s 1s/step - loss: 0.5865 - accuracy: 0.8578 - val_loss: 0.4742 - val_accuracy: 0.9588
# Epoch 2/5
# 216/216 [==============================] - 165s 763ms/step - loss: 0.4152 - accuracy: 0.9648 - val_loss: 0.3588 - val_accuracy: 0.9803
# Epoch 3/5
# 216/216 [==============================] - 165s 762ms/step - loss: 0.3252 - accuracy: 0.9704 - val_loss: 0.2904 - val_accuracy: 0.9809
# Epoch 4/5
# 216/216 [==============================] - 165s 762ms/step - loss: 0.2703 - accuracy: 0.9726 - val_loss: 0.2452 - val_accuracy: 0.9814
# Epoch 5/5
# 216/216 [==============================] - 165s 763ms/step - loss: 0.2311 - accuracy: 0.9759 - val_loss: 0.2124 - val_accuracy: 0.9809

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
val_data = tf.keras.utils.image_dataset_from_directory(train, image_size=(256, 256), labels="inferred", label_mode="binary", validation_split=0.2, subset="validation", seed=42)
val_data = val_data.map(scale_images)

true_labels = []
predicted_labels = []

threshold = 0.5

for batch in val_data:
    images, labels = batch
    predictions = model.predict(images)
    predicted_labels.extend((predictions > threshold).astype(int))
    true_labels.extend(labels.numpy().astype(int))

confusion = confusion_matrix(true_labels, predicted_labels)

class_labels = ["not_fractured", "fractured"]

plt.figure(figsize=(8, 6))
plt.imshow(confusion, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(class_labels))
plt.xticks(tick_marks, class_labels)
plt.yticks(tick_marks, class_labels)

thresh = confusion.max() / 2.0
for i, j in itertools.product(range(confusion.shape[0]), range(confusion.shape[1])):
    plt.text(j, i, format(confusion[i, j], 'd'),
             horizontalalignment="center",
             color="white" if confusion[i, j] > thresh else "black")

plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Found 8621 files belonging to 2 classes.
# Using 1724 files for validation.
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 204ms/step
